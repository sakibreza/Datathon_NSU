# %%
path="C:\\Users\\Amit Hasan\\Downloads\\4-1_semister\\monny\\Data_analysis_tutorials\\dataset\\final_dataframe.csv"

df=pd.read_csv(path)
df
# Out:
#       id    activity      time_min      time_max  time_average  x_min  y_min  \
# 0    1.0     Walking  4.991920e+12  5.974870e+12  5.472666e+12 -19.61  -5.79
# 1    1.0     Jogging  5.374660e+12  6.298490e+12  5.854316e+12 -19.61 -19.61
# 2    1.0    Upstairs  6.489310e+12  6.848770e+12  6.668160e+12 -19.61 -13.95
# 3    1.0  Downstairs  6.552940e+12  6.895550e+12  6.726542e+12 -19.61  -5.01
# 4    3.0     Walking  7.981270e+12  1.001250e+13  9.028226e+12 -19.50  -3.21
# ..   ...         ...           ...           ...           ...    ...    ...
# 174  1.0     Jogging  0.000000e+00  1.407510e+13  1.357252e+13 -18.05 -13.99
# 175  1.0     Sitting  1.480780e+13  1.493280e+13  1.487030e+13  -5.86  -3.06
# 176  1.0    Upstairs  0.000000e+00  1.469360e+13  1.441275e+13  -7.27  -0.69
# 177  1.0  Downstairs  1.423580e+13  1.477560e+13  1.450638e+13  -8.24  -2.45
# 178  1.0    Standing  1.495300e+13  1.504920e+13  1.500110e+13  -2.14   8.77
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib.pyplot import rcParams

# %matplotlib inline
rcParams["figure.figsize"]=10,7
sb.set_style("whitegrid")

# %%
#sb.pairplot(df)

# %%
df.columns
# Out:
# Index(['id', 'activity', 'time_min', 'time_max', 'time_average', 'x_min',
#        'y_min', 'z_min', 'x_std', 'y_std', 'z_std', 'x_var', 'y_var', 'z_var',
#        'x_median', 'y_median', 'z_median', 'x_mean', 'y_mean', 'z_mean',
#        'x_max', 'y_max', 'z_max', 'label'],
#       dtype='object')

# %%
df.plot(kind="scatter",y="x_min",x="label",c="red",s=10)
plt.title("X_MIN / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'X_MIN / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="y_min",x="label")
plt.title("Y_MIN / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Y_MIN / LABEL GRAPH')

# %%
df.plot(kind="scatter",x="label",y="z_min",s=10)
plt.title("Z_MIN / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Z_MIN / LABEL GRAPH')

# %%
df.plot(kind="hist",y="z_min",x="label")
plt.title("Z_MIN / LABEL HISTOGRAM GRAPH")
# Out:
# Text(0.5, 1.0, 'Z_MIN / LABEL HISTOGRAM GRAPH')

# %%
df.plot(kind="box",y="z_min",x="label")
plt.title("Z_MIN / LABEL BOX_GRAPH")
# Out:
# Text(0.5, 1.0, 'Z_MIN / LABEL BOX_GRAPH')

# %%
df.plot(kind="scatter",y="x_min",x="label")
plt.title("X_MIN / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'X_MIN / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="x_std",x="label")
plt.title("X_STD / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'X_STD / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="y_std",x="label")
plt.title("Y_STD / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Y_STD / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="y_std",x="label")
plt.title("Y_STD / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Y_STD / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="z_std",x="label")
plt.title("Z_STD / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Z_STD / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="x_var",x="label")
plt.title("X_VAR / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'X_VAR / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="y_var",x="label")
plt.title("Y_VAR / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Y_VAR / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="z_var",x="label")
plt.title("Z_VAR / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Z_VAR / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="x_median",x="label")
plt.title("X_MEDIAN / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'X_MEDIAN / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="y_median",x="label")
plt.title("Y_MEDIAM / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Y_MEDIAM / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="z_median",x="label")
plt.title("Z_MEDIAN / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Z_MEDIAN / LABEL GRAPH')

# %%
df.plot(kind="scatter",y="x_mean",x="label")

# %%
df.plot(kind="scatter",y="y_mean",x="label")

# %%
df.plot(kind="scatter",y="z_mean",x="label")

# %%
df.plot(kind="box",y="z_mean",x="label")

# %%
df.plot(kind="scatter",y="x_max",x="label")
plt.title("X_MAX / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'X_MAX / LABEL GRAPH')

# %%
df.plot(kind="box",y="x_max",x="label")

# %%
df.plot(kind="scatter",y="y_max",x="label")
plt.title("Y_MAX / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Y_MAX / LABEL GRAPH')

# %%
df.plot(kind="box",y="y_max",x="label")

# %%
df.plot(kind="scatter",y="z_max",x="label")
plt.title("Z_MAX / LABEL GRAPH")
# Out:
# Text(0.5, 1.0, 'Z_MAX / LABEL GRAPH')

# %%
df.plot(kind="box",y="z_max",x="label")
